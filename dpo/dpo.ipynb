# %% [markdown]
# ### Step 1: Install necesscary packages

# %%
# %pip install matplotlib
# %pip install torch numpy transformers datasets tiktoken wandb tqdm
# Out:
# Requirement already satisfied: matplotlib in /Users/tessatan/Documents/NTU COM SCIENCE SCREAMING CRYING/Y4S1/SC3000 Artificial Intelligence/NanoGPT-Math/nano-gpt-venv/lib/python3.12/site-packages (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/tessatan/Documents/NTU COM SCIENCE SCREAMING CRYING/Y4S1/SC3000 Artificial Intelligence/NanoGPT-Math/nano-gpt-venv/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/tessatan/Documents/NTU COM SCIENCE SCREAMING CRYING/Y4S1/SC3000 Artificial Intelligence/NanoGPT-Math/nano-gpt-venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/tessatan/Documents/NTU COM SCIENCE SCREAMING CRYING/Y4S1/SC3000 Artificial Intelligence/NanoGPT-Math/nano-gpt-venv/lib/python3.12/site-packages (from matplotlib) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/tessatan/Documents/NTU COM SCIENCE SCREAMING CRYING/Y4S1/SC3000 Artificial Intelligence/NanoGPT-Math/nano-gpt-venv/lib/python3.12/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /Users/tessatan/Documents/NTU COM SCIENCE SCREAMING CRYING/Y4S1/SC3000 Artificial Intelligence/NanoGPT-Math/nano-gpt-venv/lib/python3.12/site-packages (from matplotlib) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in /Users/tessatan/Documents/NTU COM SCIENCE SCREAMING CRYING/Y4S1/SC3000 Artificial Intelligence/NanoGPT-Math/nano-gpt-venv/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/tessatan/Documents/NTU COM SCIENCE SCREAMING CRYING/Y4S1/SC3000 Artificial Intelligence/NanoGPT-Math/nano-gpt-venv/lib/python3.12/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/tessatan/Documents/NTU COM SCIENCE SCREAMING CRYING/Y4S1/SC3000 Artificial Intelligence/NanoGPT-Math/nano-gpt-venv/lib/python3.12/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/tessatan/Documents/NTU COM SCIENCE SCREAMING CRYING/Y4S1/SC3000 Artificial Intelligence/NanoGPT-Math/nano-gpt-venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/tessatan/Documents/NTU COM SCIENCE SCREAMING CRYING/Y4S1/SC3000 Artificial Intelligence/NanoGPT-Math/nano-gpt-venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting torch
#   Downloading torch-2.8.0-cp312-none-macosx_11_0_arm64.whl.metadata (30 kB)
# Requirement already satisfied: numpy in /Users/tessatan/Documents/NTU COM SCIENCE SCREAMING CRYING/Y4S1/SC3000 Artificial Intelligence/NanoGPT-Math/nano-gpt-venv/lib/python3.12/site-packages (2.3.3)
# Collecting transformers
#   Downloading transformers-4.56.2-py3-none-any.whl.metadata (40 kB)
# Collecting datasets
#   Downloading datasets-4.1.1-py3-none-any.whl.metadata (18 kB)
# Collecting tiktoken
#   Downloading tiktoken-0.11.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting wandb
#   Downloading wandb-0.22.0-py3-none-macosx_12_0_arm64.whl.metadata (10 kB)
# Collecting tqdm
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting filelock (from torch)
#   Using cached filelock-3.19.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/tessatan/Documents/NTU COM SCIENCE SCREAMING CRYING/Y4S1/SC3000 Artificial Intelligence/NanoGPT-Math/nano-gpt-venv/lib/python3.12/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /Users/tessatan/Documents/NTU COM SCIENCE SCREAMING CRYING/Y4S1/SC3000 Artificial Intelligence/NanoGPT-Math/nano-gpt-venv/lib/python3.12/site-packages (from torch) (80.9.0)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch)
#   Downloading networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jinja2 in /Users/tessatan/Documents/NTU COM SCIENCE SCREAMING CRYING/Y4S1/SC3000 Artificial Intelligence/NanoGPT-Math/nano-gpt-venv/lib/python3.12/site-packages (from torch) (3.1.6)
# Collecting fsspec (from torch)
#   Using cached fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting huggingface-hub<1.0,>=0.34.0 (from transformers)
#   Downloading huggingface_hub-0.35.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/tessatan/Documents/NTU COM SCIENCE SCREAMING CRYING/Y4S1/SC3000 Artificial Intelligence/NanoGPT-Math/nano-gpt-venv/lib/python3.12/site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/tessatan/Documents/NTU COM SCIENCE SCREAMING CRYING/Y4S1/SC3000 Artificial Intelligence/NanoGPT-Math/nano-gpt-venv/lib/python3.12/site-packages (from transformers) (6.0.2)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading regex-2025.9.18-cp312-cp312-macosx_11_0_arm64.whl.metadata (40 kB)
# Requirement already satisfied: requests in /Users/tessatan/Documents/NTU COM SCIENCE SCREAMING CRYING/Y4S1/SC3000 Artificial Intelligence/NanoGPT-Math/nano-gpt-venv/lib/python3.12/site-packages (from transformers) (2.32.5)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Downloading tokenizers-0.22.1-cp39-abi3-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Using cached safetensors-0.6.2-cp38-abi3-macosx_11_0_arm64.whl.metadata (4.1 kB)
# Collecting pyarrow>=21.0.0 (from datasets)
#   Downloading pyarrow-21.0.0-cp312-cp312-macosx_12_0_arm64.whl.metadata (3.3 kB)
# Collecting dill<0.4.1,>=0.3.0 (from datasets)
#   Downloading dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting pandas (from datasets)
#   Downloading pandas-2.3.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (91 kB)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Using cached multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Collecting click>=8.0.1 (from wandb)
#   Using cached click-8.3.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb)
#   Using cached gitpython-3.1.45-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs in /Users/tessatan/Documents/NTU COM SCIENCE SCREAMING CRYING/Y4S1/SC3000 Artificial Intelligence/NanoGPT-Math/nano-gpt-venv/lib/python3.12/site-packages (from wandb) (4.4.0)
# Collecting protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 (from wandb)
#   Downloading protobuf-6.32.1-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Collecting pydantic<3 (from wandb)
#   Using cached pydantic-2.11.9-py3-none-any.whl.metadata (68 kB)
# Collecting sentry-sdk>=2.0.0 (from wandb)
#   Downloading sentry_sdk-2.38.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets)
#   Downloading aiohttp-3.12.15-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.29,>=1.0.0->wandb)
#   Using cached gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface-hub<1.0,>=0.34.0->transformers)
#   Using cached hf_xet-1.1.10-cp37-abi3-macosx_11_0_arm64.whl.metadata (4.7 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3->wandb)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<3->wandb)
#   Using cached pydantic_core-2.33.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3->wandb)
#   Using cached typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/tessatan/Documents/NTU COM SCIENCE SCREAMING CRYING/Y4S1/SC3000 Artificial Intelligence/NanoGPT-Math/nano-gpt-venv/lib/python3.12/site-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tessatan/Documents/NTU COM SCIENCE SCREAMING CRYING/Y4S1/SC3000 Artificial Intelligence/NanoGPT-Math/nano-gpt-venv/lib/python3.12/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/tessatan/Documents/NTU COM SCIENCE SCREAMING CRYING/Y4S1/SC3000 Artificial Intelligence/NanoGPT-Math/nano-gpt-venv/lib/python3.12/site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tessatan/Documents/NTU COM SCIENCE SCREAMING CRYING/Y4S1/SC3000 Artificial Intelligence/NanoGPT-Math/nano-gpt-venv/lib/python3.12/site-packages (from requests->transformers) (2025.8.3)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/tessatan/Documents/NTU COM SCIENCE SCREAMING CRYING/Y4S1/SC3000 Artificial Intelligence/NanoGPT-Math/nano-gpt-venv/lib/python3.12/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/tessatan/Documents/NTU COM SCIENCE SCREAMING CRYING/Y4S1/SC3000 Artificial Intelligence/NanoGPT-Math/nano-gpt-venv/lib/python3.12/site-packages (from pandas->datasets) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->datasets)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->datasets)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in /Users/tessatan/Documents/NTU COM SCIENCE SCREAMING CRYING/Y4S1/SC3000 Artificial Intelligence/NanoGPT-Math/nano-gpt-venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (25.3.0)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets)
#   Downloading frozenlist-1.7.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (18 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets)
#   Downloading multidict-6.6.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets)
#   Downloading propcache-0.3.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets)
#   Downloading yarl-1.20.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (73 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb)
#   Using cached smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: six>=1.5 in /Users/tessatan/Documents/NTU COM SCIENCE SCREAMING CRYING/Y4S1/SC3000 Artificial Intelligence/NanoGPT-Math/nano-gpt-venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading torch-2.8.0-cp312-none-macosx_11_0_arm64.whl (73.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 MB 9.8 MB/s eta 0:00:00:00:0100:01
# Downloading transformers-4.56.2-py3-none-any.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 10.7 MB/s eta 0:00:00a 0:00:01
# Downloading datasets-4.1.1-py3-none-any.whl (503 kB)
# Downloading tiktoken-0.11.0-cp312-cp312-macosx_11_0_arm64.whl (996 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 996.7/996.7 kB 11.5 MB/s eta 0:00:00
# Downloading wandb-0.22.0-py3-none-macosx_12_0_arm64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 9.1 MB/s eta 0:00:00a 0:00:01
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached click-8.3.0-py3-none-any.whl (107 kB)
# Downloading dill-0.4.0-py3-none-any.whl (119 kB)
# Using cached fsspec-2025.9.0-py3-none-any.whl (199 kB)
# Using cached gitpython-3.1.45-py3-none-any.whl (208 kB)
# Downloading huggingface_hub-0.35.1-py3-none-any.whl (563 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 563.3/563.3 kB 6.5 MB/s eta 0:00:00
# Using cached multiprocess-0.70.16-py312-none-any.whl (146 kB)
# Downloading protobuf-6.32.1-cp39-abi3-macosx_10_9_universal2.whl (426 kB)
# Downloading pyarrow-21.0.0-cp312-cp312-macosx_12_0_arm64.whl (31.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.2/31.2 MB 8.9 MB/s eta 0:00:0000:0100:01m
# Using cached pydantic-2.11.9-py3-none-any.whl (444 kB)
# Using cached pydantic_core-2.33.2-cp312-cp312-macosx_11_0_arm64.whl (1.8 MB)
# Downloading regex-2025.9.18-cp312-cp312-macosx_11_0_arm64.whl (287 kB)
# Using cached safetensors-0.6.2-cp38-abi3-macosx_11_0_arm64.whl (432 kB)
# Downloading sentry_sdk-2.38.0-py2.py3-none-any.whl (370 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 12.5 MB/s eta 0:00:00a 0:00:01
# Downloading tokenizers-0.22.1-cp39-abi3-macosx_11_0_arm64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 11.3 MB/s eta 0:00:00a 0:00:01
# Using cached filelock-3.19.1-py3-none-any.whl (15 kB)
# Downloading networkx-3.5-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 9.3 MB/s eta 0:00:00a 0:00:01
# Downloading pandas-2.3.2-cp312-cp312-macosx_11_0_arm64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 9.1 MB/s eta 0:00:00 0:00:01m
# Downloading xxhash-3.5.0-cp312-cp312-macosx_11_0_arm64.whl (30 kB)
# Downloading aiohttp-3.12.15-cp312-cp312-macosx_11_0_arm64.whl (469 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
# Using cached hf_xet-1.1.10-cp37-abi3-macosx_11_0_arm64.whl (2.6 MB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 7.8 MB/s eta 0:00:00
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.7.0-cp312-cp312-macosx_11_0_arm64.whl (46 kB)
# Downloading multidict-6.6.4-cp312-cp312-macosx_11_0_arm64.whl (43 kB)
# Downloading propcache-0.3.2-cp312-cp312-macosx_11_0_arm64.whl (43 kB)
# Using cached smmap-5.0.2-py3-none-any.whl (24 kB)
# Downloading yarl-1.20.1-cp312-cp312-macosx_11_0_arm64.whl (89 kB)
# Installing collected packages: pytz, mpmath, xxhash, tzdata, typing-inspection, tqdm, sympy, smmap, sentry-sdk, safetensors, regex, pydantic-core, pyarrow, protobuf, propcache, networkx, multidict, hf-xet, fsspec, frozenlist, filelock, dill, click, annotated-types, aiohappyeyeballs, yarl, torch, tiktoken, pydantic, pandas, multiprocess, huggingface-hub, gitdb, aiosignal, tokenizers, gitpython, aiohttp, wandb, transformers, datasets
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.12.15 aiosignal-1.4.0 annotated-types-0.7.0 click-8.3.0 datasets-4.1.1 dill-0.4.0 filelock-3.19.1 frozenlist-1.7.0 fsspec-2025.9.0 gitdb-4.0.12 gitpython-3.1.45 hf-xet-1.1.10 huggingface-hub-0.35.1 mpmath-1.3.0 multidict-6.6.4 multiprocess-0.70.16 networkx-3.5 pandas-2.3.2 propcache-0.3.2 protobuf-6.32.1 pyarrow-21.0.0 pydantic-2.11.9 pydantic-core-2.33.2 pytz-2025.2 regex-2025.9.18 safetensors-0.6.2 sentry-sdk-2.38.0 smmap-5.0.2 sympy-1.14.0 tiktoken-0.11.0 tokenizers-0.22.1 torch-2.8.0 tqdm-4.67.1 transformers-4.56.2 typing-inspection-0.4.1 tzdata-2025.2 wandb-0.22.0 xxhash-3.5.0 yarl-1.20.1
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Step 2: Package imports and configuration

# %%
import sys
import os
sys.path.append(os.path.abspath("..")) 
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
import torch
import torch.nn as nn
import torch.nn.functional as F
import random
import pickle
from model import GPT, GPTConfig
import random
from tqdm import tqdm
import time
import json
import matplotlib.pyplot as plt
# Configuration
beta = 0.5
device = 'cuda' if torch.cuda.is_available() else 'cpu'
base_lr = 1e-4
epochs = 5
batch_size = 64
max_length =64
num_samples = 1
max_new_tokens = 200
temperature = 0.8
top_k = 200
# tokenizer
with open("../sft/meta.pkl", "rb") as f:
    meta = pickle.load(f)
stoi, itos = meta["stoi"], meta["itos"]
def encode(s): return [stoi[c] for c in s]
def decode(l): return ''.join([itos[i] for i in l])

# %% [markdown]
# ### Step 3: Define helper functions

# %%
def compute_logprob(input_ids):
    inputs = input_ids[:, :-1]
    targets = input_ids[:, 1:]
    logits, _ = gpt(inputs, full_seq=True)
    B, T, V = logits.size()
    logits_flat = logits.reshape(-1, V)
    targets_flat = targets.reshape(-1)
    loss = F.cross_entropy(logits_flat, targets_flat, ignore_index=0, reduction='none')
    loss = loss.reshape(B, T)
    attention_mask = (targets != 0).float()
    loss = (loss * attention_mask).sum(dim=1) / attention_mask.sum(dim=1)
    return -loss 

def pad_or_truncate(seq, max_length):
    return seq[-max_length:] if len(seq) > max_length else seq + [0] * (max_length - len(seq))

def get_batches(lines, batch_size):
    random.shuffle(lines)
    #for l in lines:
    #    print(l[1])
    for i in range(0, len(lines), batch_size):
        batch = lines[i:i+batch_size]
        if len(batch) < batch_size:
            continue
        neg_inputs = [pad_or_truncate(encode(p['negative'] + '\n\n\n\n'), max_length) for p in batch]
        pos_inputs = [pad_or_truncate(encode(p['positive'] + '\n\n\n\n'), max_length) for p in batch]
        neg_tensor = torch.tensor(neg_inputs, dtype=torch.long, device=device)
        pos_tensor = torch.tensor(pos_inputs, dtype=torch.long, device=device)
        yield neg_tensor, pos_tensor

# %% [markdown]
# ### Step 4: Load the pretrained NanoGPT model

# %%
ckpt = torch.load("../sft/gpt.pt", map_location=device)
gptconf = GPTConfig(**ckpt['model_args'])
gpt = GPT(gptconf)
state_dict = ckpt['model']
unwanted_prefix = '_orig_mod.'
for k in list(state_dict.keys()):
    if k.startswith(unwanted_prefix):
        state_dict[k[len(unwanted_prefix):]] = state_dict.pop(k)
gpt.load_state_dict(state_dict)
gpt.to(device).train()
# Out:
# GPT(
#   (transformer): ModuleDict(
#     (wte): Embedding(74, 348)
#     (wpe): Embedding(256, 348)
#     (drop): Dropout(p=0.2, inplace=False)
#     (h): ModuleList(
#       (0-5): 6 x Block(
#         (ln_1): LayerNorm()
#         (attn): CausalSelfAttention(
#           (c_attn): Linear(in_features=348, out_features=1044, bias=False)
#           (c_proj): Linear(in_features=348, out_features=348, bias=False)
#           (attn_dropout): Dropout(p=0.2, inplace=False)
#           (resid_dropout): Dropout(p=0.2, inplace=False)
#         )
#         (ln_2): LayerNorm()
#         (mlp): MLP(
#           (c_fc): Linear(in_features=348, out_features=1392, bias=False)
#           (gelu): GELU(approximate='none')
#           (c_proj): Linear(in_features=1392, out_features=348, bias=False)
#           (dropout): Dropout(p=0.2, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm()
#   )
#   (lm_head): Linear(in_features=348, out_features=74, bias=False)
# )

# %% [markdown]
# ### Step 5: Load Data (**students are required to complete this part!**)

# %%
# Load data from ./data/pos_neg_pairs.json
with open("pos_neg_pairs.json", "r", encoding="utf-8") as f:
    lines = json.load(f)

print(f"Loaded {len(lines)} positive-negative pairs")
# Out:
# Loaded 100000 positive-negative pairs

# %% [markdown]
# ### Step 6: Build the optimizer and scheduler (**students are required to complete this part!**)

# %%
# recommend to use the AdamW optimizer 
optimizer = torch.optim.AdamW(gpt.parameters(), lr=base_lr, weight_decay=0.01)

from torch.optim.lr_scheduler import LambdaLR

def lr_lambda(current_step):
    warmup_steps = 500
    if current_step < warmup_steps:
        return float(current_step) / float(max(1, warmup_steps))
    return max(0.0, float(total_steps - current_step) / float(max(1, total_steps - warmup_steps)))

total_steps = len(lines) // batch_size * epochs
scheduler = LambdaLR(optimizer, lr_lambda)

# %% [markdown]
# ### Step 7: Begin training (**students are required to complete this part!**)

# %%
total_steps = len(lines) // batch_size
for epoch in range(epochs):
    pbar = tqdm(get_batches(lines, batch_size))
    for step, (neg_tensor,pos_tensor) in enumerate(pbar):
        # Compute logprobs
        neg_logprob = compute_logprob(neg_tensor)
        pos_logprob = compute_logprob(pos_tensor)

        # DPO loss
        loss = -F.logsigmoid((pos_logprob - neg_logprob) / beta).mean()
        loss += - pos_logprob.mean() * 0.1   # optional preference boost

        # Backprop
        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(gpt.parameters(), 1.0)
        optimizer.step()
        scheduler.step()

        # Progress bar
        pbar.set_description(f"Epoch {epoch+1}, Step {step}, Loss {loss.item():.4f}")
    ckpt_path = f"./dpo.pt"

    torch.save({
        "model_state_dict": gpt.state_dict(),
        "model_args": ckpt['model_args'],
    }, ckpt_path)
    print(f"Saved checkpoint to {ckpt_path}")
# Out:
# Epoch 1, Step 296, Loss 0.0929: : 297it [07:38,  1.32s/it]

# %% [markdown]
# ### Step 8: Begin testing (**students are required to complete this part!**)

# %%
# Load the fine-tuned model
ckpt_path = "../dpo/dpo.pt"
checkpoint = torch.load(ckpt_path, map_location=device)
gptconf = GPTConfig(**checkpoint['model_args'])
gpt = GPT(gptconf).cuda()
try:
    state_dict = checkpoint['model']
except:
    state_dict = checkpoint['model_state_dict']
unwanted_prefix = '_orig_mod.'
for k,v in list(state_dict.items()):
    if k.startswith(unwanted_prefix):
        state_dict[k[len(unwanted_prefix):]] = state_dict.pop(k)
gpt.load_state_dict(state_dict)
# Test
gpt.eval()
test_set = ["17+19=?", "3*17=?", "72/4=?", "72-x=34,x=?", "x*11=44,x=?", "3*17=?", "72/4=?", "72-x=34,x=?"]
with torch.no_grad():
    for prompt in test_set: 
        prompt_ids = encode(prompt)
        ###########################################################
        # Please complete the test code here!
        # ...
        # gpt.generate(x, max_new_tokens, temperature=temperature, top_k=top_k)
        # ...
        ###########################################################
